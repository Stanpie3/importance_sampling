altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/tv_studio/nice_casino_50_16_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/tv_studio/plato_de_television_01_03_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/tv_studio/tv_studio_01_03_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/tv_studio/tv_studio_01_18_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/tv_studio/tv_studio_03_03_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/tv_studio/tv_studio_03_18_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/tv_studio/tv_studio_05_12_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/tv_studio/tv_studio_06_08_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/tv_studio/tv_studio_11_13_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/tv_studio/tv_studio_19_02_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/tv_studio/tv_studio_29_06_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/tv_studio/tv_studio_32_12_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/tv_studio/tv_studio_40_01_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/tv_studio/tv_studio_40_12_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/tv_studio/tv_studio_48_15_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/videostore/mws_STOREINT.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/videostore/video_store_43_09_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/videostore/videoclub_01_15_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/videostore/videoclub_03_19_flickr.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/videostore/videoclub_03_24_flickr.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/videostore/videoclub_04_02_yahoo.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/videostore/videoclub_07_11_flickr.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/videostore/videoclub_07_15_flickr.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/videostore/videoclub_09_17_flickr.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/videostore/videoclub_14_07_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/videostore/videoclub_34_03_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/videostore/videoteca_07_03_flickr.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/videostore/videoteca_07_04_flickr.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/videostore/videoteca_07_05_flickr.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/videostore/videoteka_04_03_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/videostore/videotheque_01_22_flickr.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/videostore/videotheque_02_01_flickr.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/waitingroom/11.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/waitingroom/400_Waiting_Room_2.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/waitingroom/7.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/waitingroom/800px_VTBS_Waiting_room_of_Thai_Airways.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/waitingroom/PatientWaitingRoom.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/waitingroom/Waiting-room.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/waitingroom/Waiting_Room_sm.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/waitingroom/a67092.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/waitingroom/cab3.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/waitingroom/patient_waiting_room.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/waitingroom/photo_1241582.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/waitingroom/salleAttente.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/waitingroom/url_1.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/waitingroom/waitroom127.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0001.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0006.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0011.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0021.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0026.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0031.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0036.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0041.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0046.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0051.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0056.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0062.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0066.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0071.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0076.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0081.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0084.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0086.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0091.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0094.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0096.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0101.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0111.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0116.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0121.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0126.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0131.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0136.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0151.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0161.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0166.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0171.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0176.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0181.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0186.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0191.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0194.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0196.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0206.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0211.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0216.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0221.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0231.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0235.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0241.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0269.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0325.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0371.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0376.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0447.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0458.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0467.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/warehouse/warehouse_0486.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/winecellar/1184099831156_02.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/winecellar/bodega2.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/winecellar/bodega_101_07_flickr.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/winecellar/bodega_12_11_flickr.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/winecellar/bodega_36_10_yahoo.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/winecellar/bodega_38_21_yahoo.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/winecellar/bodega_88_08_flickr.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/winecellar/bodega_vino_03_10_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/winecellar/cave_champagne_01_19_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/winecellar/cave_champagne_05_15_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/winecellar/cave_champagne_06_08_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/winecellar/cave_champagne_07_11_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/winecellar/wine_cellar_30_20_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/winecellar/wine_cellar_48_12_altavista.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/winecellar/wine_cellar_air_conditioning.xml
#   inflating: MIT-671/indoorCVPR_09annotations/Annotations/winecellar/wine_storage_42_02_altavista.xml

# %%
# !git clone https://github.com/Stanpie3/importance_sampling.git
# !mv importance_sampling/* .
# !rm -r importance_sampling
# Out:
# Cloning into 'importance_sampling'...

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from src.train_importance_sampling import VarReductionCondition, get_g
from src.utils.common import Accumulator

def train_batch_is(model,
                x_batch,
                y_batch,
                loss_fn,
                optimizer,
                accumulator : Accumulator,
                condition : VarReductionCondition,
                presample = 3.0,
                use_loss_estimation = False,
                second_approach = False):

    flag = False
    model.train()
    model.zero_grad()

    batch_size = x_batch.shape[0]

    selected_batch_size = int(batch_size / presample)

    if condition.satisfied :
        if second_approach:
            with torch.no_grad(): output = model(x_batch)
        #print("condition satisfied")
        else:
            output = model(x_batch)
            
        g_i_norm = get_g(output, y_batch, loss_fn, use_loss_estimation  )
        condition.update(g_i_norm)
        flag = True
    else:
        #print("condition not satisfied")
        g_i_norm = np.ones(batch_size)


    p_i = g_i_norm / np.sum(g_i_norm)
    batch_indices = np.random.choice(np.arange(batch_size), size = selected_batch_size, replace=True, p=p_i)

    selected_p_i = p_i[batch_indices]

    if condition.previously_satisfied:
        #if
        if second_approach:
            output = model(x_batch[batch_indices])
            y_batch = y_batch[batch_indices]
            loss = loss_fn(output, y_batch)
            selected_loss = loss
            loss = loss_fn(output, y_batch)
        else:
            loss = loss_fn(output, y_batch)
            selected_loss = loss[batch_indices]
    else :
        output = model(x_batch[batch_indices])
        y_batch = y_batch[batch_indices]
        condition.update( get_g(output, y_batch, loss_fn, use_loss_estimation ) )
        loss = loss_fn(output, y_batch)
        selected_loss = loss

    w_i = 1.0 / (batch_size * selected_p_i)

    weighted_loss = (torch.tensor(w_i).to(selected_loss.device).detach() * selected_loss).mean()

    weighted_loss.backward()

    optimizer.step()

    max_p_i = np.max(p_i)
    num_unique_points = np.unique(batch_indices).size


    n = len(output)
    with torch.no_grad():
        batch_loss = loss.mean().cpu().item()
        weighted_batch_loss = weighted_loss.mean().cpu().item()
        batch_acc_sum = (output.argmax(dim=1) == y_batch).sum().cpu().item()/n


    accumulator.average(
        train_loss = ( batch_loss, n) ,
        train_acc = ( batch_acc_sum, n) ,
        train_w_loss = ( weighted_batch_loss, selected_batch_size) ,
        train_uniform_cnt = flag)

    accumulator.store(
        max_p_i = max_p_i ,
        num_unique_points = num_unique_points)

# %%
def train_full(model, train_dataloader, loss_fn, optimizer, n_epochs, eval = None, callback=None, presample=2, tau_th = None, use_loss_estimation = False, second_approach=False):
    epochs = tqdm(range(n_epochs), desc='Epochs', leave=True)

    large_batch = int( train_dataloader.batch_size)

    # Compute the threshold using eq. 29 in
    # https://arxiv.org/abs/1803.00942

    B = large_batch
    b = int( large_batch / presample)
    tau_th = float(B + 3*b) / (3*b) if tau_th is None else   tau_th

    condition = VarReductionCondition(tau_th)

    if callback :
        callback.setMeta(
            large_batch = large_batch,
            n_epochs = n_epochs,
            presample = presample,
            tau_th = tau_th,
            use_loss_estimation = use_loss_estimation)


    for i_epoch in epochs:
        accum = Accumulator()

        for i_batch, (X_batch, y_batch) in enumerate(train_dataloader):
            train_batch_is( model,
                            X_batch.to(model.device),
                            y_batch.to(model.device),
                            loss_fn,
                            optimizer,
                            accum,
                            condition,
                            presample,
                            use_loss_estimation)

        if callback :
            val_scores = eval(model) if eval else {}
            #print(condition.string + f" n_un={callback.n_un[-1]}")
            cb_dict = callback( **accum.getAll(), **val_scores)
            print(condition.string)
            epochs.set_postfix(cb_dict)

# %%
def evaluate(model, dataloader, loss_fn):
    model.eval()
    logits = []
    targets = []
    with torch.no_grad():
        for X_batch, y_batch in dataloader:
            output = model(X_batch.to(model.device)).cpu()
            logits.append(output)
            targets.append(y_batch)
    logits = torch.cat(logits)
    targets = torch.cat(targets)
    loss = loss_fn(logits, targets).mean().item()
    acc = (logits.argmax(dim=1) == targets).sum().item() / len(targets)
    return loss, acc

# %%
import torch
from torchvision import transforms, datasets

# Define the data transformation pipeline
#train_transform = transforms.Compose([
#    transforms.RandomRotation(30),
#    transforms.CenterCrop(224),
#    transforms.RandomHorizontalFlip(),
#    transforms.ToTensor(),
#    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#    ])

train_transform = transforms.Compose([
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])



#data_transform = transforms.Compose([
#    transforms.Resize((224, 224)),     # Resize the image to (224, 224)
#    transforms.ToTensor(),             # Convert image to tensor
#    transforms.Normalize(
#        mean=[0.485, 0.456, 0.406],
#        std=[0.229, 0.224, 0.225]
#        ),
#    ])

data_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
        ),
    ])



# Specify the root directory of your dataset
data_dir = 'MIT-671/indoorCVPR_09/Images/'

# Create an instance of the ImageFolder dataset
train_dataset = datasets.ImageFolder(root=data_dir, transform=train_transform)
test_dataset = datasets.ImageFolder(root=data_dir, transform=data_transform)



dataset_size = len(train_dataset)
indices = list(range(dataset_size))

from torch.utils.data.sampler import SubsetRandomSampler
from sklearn.model_selection import train_test_split

train_idx, test_idx = train_test_split(indices, test_size=0.25)
print(len(train_idx), len(test_idx))

# Create a DataLoader to load data in batches
batch_size = 64

train_sampler = SubsetRandomSampler(train_idx)
test_sampler = SubsetRandomSampler(test_idx)

train_dataloader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=batch_size,
    #shuffle=True,
    sampler=train_sampler
    )

val_dataloader = torch.utils.data.DataLoader(
    test_dataset,
    batch_size=batch_size,
    #shuffle=True,
    sampler=test_sampler
    )
# Out:
# 11715 3905

# %%
#from data_loaders import train_val_dataloader, test_dataloader

#train_dataloader, val_dataloader = train_val_dataloader(batch_size=32)#128*3
#test_loader = test_dataloader(batch_size=120)

# %%
# %load_ext autoreload

# %aimport common_utils
# %autoreload 1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 1
from models import ResNet50
from torchvision.models import resnet50
from common_utils import UnCallBack

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
#model = ResNet50()
#model = resnet50(pretrained=True)
model = nn.Sequential(
    resnet50(pretrained=True),
    # Since the resnet34 from torch was trained on ImageNet with 1000 classes, we need additional lineal layer for 10 classes in CIFAR10
    nn.Linear(1000, 67)
)
model.to(device)
model.device = device

loss_fn = nn.CrossEntropyLoss(reduction='none')
#optimizer = torch.optim.AdamW(model.parameters(), lr = 1e-3 )
optimizer = torch.optim.SGD(model.parameters(), lr = 1e-3, momentum=0.9)


callback = UnCallBack( info_list = ['train_loss', 'train_acc', 'train_w_loss', 'val_loss', 'val_acc', 'train_uniform_cnt'])

def eval_callback(model):
    loss, acc =evaluate(model, val_dataloader, loss_fn)
    return {"val_loss": loss, "val_acc": acc}

train_full(model, train_dataloader, loss_fn, optimizer, n_epochs=20, eval=eval_callback, callback=callback, presample=3, tau_th = 10, use_loss_estimation = False,
second_approach = False)
# callback.save("loss_estimation")
# callback.save("callback")
callback.save("uniform")
# Out:
# cuda
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epochs:   0%|          | 0/20 [00:00<?, ?it/s]
# vr=1.140,  vr_th=10.000
# vr=1.185,  vr_th=10.000
# vr=1.293,  vr_th=10.000
# vr=1.338,  vr_th=10.000
# vr=1.391,  vr_th=10.000
# vr=1.507,  vr_th=10.000
# vr=1.519,  vr_th=10.000
# vr=1.534,  vr_th=10.000
# vr=1.680,  vr_th=10.000
# vr=1.722,  vr_th=10.000
# vr=1.727,  vr_th=10.000
# vr=1.788,  vr_th=10.000
# vr=1.873,  vr_th=10.000
# vr=1.907,  vr_th=10.000
# vr=2.096,  vr_th=10.000
# vr=2.129,  vr_th=10.000
# vr=2.187,  vr_th=10.000
# vr=2.081,  vr_th=10.000
# vr=2.317,  vr_th=10.000
# vr=2.467,  vr_th=10.000

# %%
from common_utils import UnCallBack
callback = UnCallBack.load("callback.pickle")
callback2 = UnCallBack.load("loss_estimation.pickle")
callback3 = UnCallBack.load("uniform.pickle")

# %%
loss, acc = evaluate(model, val_dataloader, loss_fn)
print(f'ResNet50, test loss: {loss}')
print(f'ResNet50, test accuracy: {acc}')
# Out:
# ResNet50, test loss: 5.106550216674805
# ResNet50, test accuracy: 0.012291933418693982

# %%
plt.figure(figsize=(15, 10))
plt.title('ResNet50, train and validation loss')
plt.xlabel('Number of epoch')
plt.ylabel('Loss')

epochs = np.arange(len(callback.train_loss) - 20) + 1
epochs1 = np.arange(len(callback.train_loss)) + 1
plt.plot(epochs1, callback.train_loss , label=f'upper-bound, min: {np.min(callback.train_loss):.3f}')
plt.plot(epochs, callback2.train_loss , label=f'loss-based, min: {np.min(callback2.train_loss):.3f}')
plt.plot(epochs, callback3.train_loss , label=f'uniform, min: {np.min(callback3.train_loss):.3f}')
# plt.plot(epochs, callback.train_w_loss , label='Train weighted')
# plt.plot(epochs, callback.val_loss , label=f'Validation, min: {np.min(callback.val_loss):.3f}')
plt.legend()
plt.grid(True)

# %%
print(f'Best loss on train: {np.min(callback.train_loss)}, on {np.argmin(callback.train_loss) + 1} epoch')
# print(f'Best weighted loss on train: {np.min(callback.train_w_loss)}, on {np.argmin(callback.train_w_loss) + 1} epoch')
print(f'Best loss on validation: {np.min(callback.val_loss)}, on {np.argmin(callback.val_loss) + 1} epoch')
# Out:
# Best loss on train: 0.012385510434160057, on 27 epoch
# Best loss on validation: 1.06013023853302, on 13 epoch

# %%
plt.figure(figsize=(15, 10))
plt.title('ResNet50, train and validation error')
plt.xlabel('Number of epoch')
plt.ylabel('Error')
leng1 = len(callback.train_acc)
leng2 = len(callback.val_acc)
epochs = np.arange(len(callback.train_acc)) + 1
plt.plot(epochs, np.ones(leng1) - np.array(callback.train_acc), label=f'Train, acc: {np.max(callback.train_acc):.3f}')
plt.plot(epochs, np.ones(leng2) - np.array(callback.val_acc), label=f'Validation, acc:{np.max(callback.val_acc):.3f}')
plt.legend()
plt.grid(True)

# %%
plt.figure(figsize=(15, 10))
plt.title('ResNet50, train and validation error')
plt.xlabel('Number of epoch')
plt.ylabel('Error')
leng1 = len(callback2.train_acc)
leng2 = len(callback.val_acc)
epochs = np.arange(len(callback.train_acc)) + 1
epochs1 = np.arange(len(callback2.train_acc)) + 1
plt.plot(epochs, np.ones(leng2) - np.array(callback.val_acc), label=f'upper-bound val, acc:{np.max(callback.val_acc):.3f}')
plt.plot(epochs1, np.ones(leng1) - np.array(callback2.val_acc), label=f'loss-based val, acc:{np.max(callback2.val_acc):.3f}')
plt.plot(epochs1, np.ones(leng1) - np.array(callback3.val_acc), label=f'uniform val, acc:{np.max(callback3.val_acc):.3f}')
plt.legend()
plt.grid(True)

# %%
print(f'Best accuracy on train: {np.max(callback.train_acc)}, on {np.argmax(callback.train_acc) + 1} epoch')
print(f'Best accuracy on validation: {np.max(callback.val_acc)}, on {np.argmax(callback.val_acc) + 1} epoch')
# Out:
# Best accuracy on train: 0.9976952624839949, on 18 epoch
# Best accuracy on validation: 0.7257362355953906, on 13 epoch
